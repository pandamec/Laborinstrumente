# %%
import sys
sys.path.append(r"E:\00 Script\Laborinstrumente\src") # Replace by your path
import Atto800

# %%
sys.path.append(r"E:\00 Script\Laborinstrumente\src") # Replace by your path
import AttoDry800SoftControl

# %%
## Configuration
IP = "192.168.1.1"
Atto=Atto800.Device(IP)
Atto.connect()

# %%
AttoSoftControl=AttoDry800SoftControl.attoDryControl(Atto, 1,1)

# %%
AttoSoftControl.performApproach(300)
# Out:
# Performing an Approach during Heating
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 AttoSoftControl.performApproach(300)
#
# File E:\00 Script\Laborinstrumente\src\AttoDry800SoftControl\SoftControl.py:177, in attoDryControl.performApproach(self, T_target)
#     175 if self.AttoMode == 1: #Heating
#     176     print("Performing an Approach during Heating")
# --> 177     self.performApproachHeating(T_target)
#     178     print("Approach finished at Sample Plate")
#     180 elif self.AttoMode==2: #Cooling down
#
# File E:\00 Script\Laborinstrumente\src\AttoDry800SoftControl\SoftControl.py:101, in attoDryControl.performApproachHeating(self, T_targetSample)
#      98 while n_dTds < 10:
#     100     self.startControl(T_targetSample)
# --> 101     dTds = self.getcoolingrateSample(2)
#     102     Ts = self.Atto.sample.getTemperature()
#     103     Delta = T_targetSample - Ts
#
# File E:\00 Script\Laborinstrumente\src\AttoDry800SoftControl\SoftControl.py:56, in attoDryControl.getcoolingrateSample(self, seconds)
#      54 """Compute the cooling rate in a  determined delta time t"""
#      55 TS1 = self.Atto.sample.getTemperature()
# ---> 56 time.sleep(seconds)
#      57 TS2 = self.Atto.sample.getTemperature()
#      59 dTds = (TS2 - TS1) / seconds
#
# NameError: name 'time' is not defined
