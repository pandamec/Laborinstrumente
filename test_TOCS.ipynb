# %% [markdown]
# ## Preamble

# %%
import sys

# %%
sys.path.append(r"C:\TUC\03 Scripts\Laborinstrumente\src") # Replace by your path
import TOCS

# %% [markdown]
# ## Getting started

# %%
WINDOW_TITLE="134.109.28.184"

# %%
tocs=TOCS.Device(WINDOW_TITLE)

# %%
tocs.run_measurement(5*60)
# Out:
# Activated window: 134.109.28.184 - Remote Desktop Connection
# Searching for: C:\TUC\03 Scripts\Laborinstrumente\src\TOCS\icons\measurement.png
# Found C:\TUC\03 Scripts\Laborinstrumente\src\TOCS\icons\measurement.png at (293, 115)
# Searching for: C:\TUC\03 Scripts\Laborinstrumente\src\TOCS\icons\save.png
# Found C:\TUC\03 Scripts\Laborinstrumente\src\TOCS\icons\save.png at (354, 114)
# Searching for: C:\TUC\03 Scripts\Laborinstrumente\src\TOCS\icons\export.png
# Found C:\TUC\03 Scripts\Laborinstrumente\src\TOCS\icons\export.png at (417, 116)
# Searching for: C:\TUC\03 Scripts\Laborinstrumente\src\TOCS\icons\msadd.png
# Found C:\TUC\03 Scripts\Laborinstrumente\src\TOCS\icons\msadd.png at (529, 86)
# Searching for: C:\TUC\03 Scripts\Laborinstrumente\src\TOCS\icons\mnew.png
# Found C:\TUC\03 Scripts\Laborinstrumente\src\TOCS\icons\mnew.png at (549, 87)
# Searching for: C:\TUC\03 Scripts\Laborinstrumente\src\TOCS\icons\closeothers.png
# ...
