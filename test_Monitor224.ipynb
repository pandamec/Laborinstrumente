# %%
pip install pyserial
# Out:
# Collecting pyserial
#   Using cached pyserial-3.5-py2.py3-none-any.whl.metadata (1.6 kB)
# Using cached pyserial-3.5-py2.py3-none-any.whl (90 kB)
# Installing collected packages: pyserial
# Successfully installed pyserial-3.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install lakeshore
# Out:
# Collecting lakeshore
#   Using cached lakeshore-1.10.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pyserial>=3.0 in c:\tuc\03 scripts\laborinstrumente\.venv\lib\site-packages (from lakeshore) (3.5)
# Collecting iso8601 (from lakeshore)
#   Using cached iso8601-2.1.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: packaging in c:\tuc\03 scripts\laborinstrumente\.venv\lib\site-packages (from lakeshore) (26.3)
# Collecting wakepy>=0.7.1 (from lakeshore)
#   Using cached wakepy-1.0.0-py3-none-any.whl.metadata (18 kB)
# Using cached lakeshore-1.10.0-py3-none-any.whl (127 kB)
# Using cached wakepy-1.0.0-py3-none-any.whl (70 kB)
# Using cached iso8601-2.1.0-py3-none-any.whl (7.5 kB)
# Installing collected packages: wakepy, iso8601, lakeshore
# Successfully installed iso8601-2.1.0 lakeshore-1.10.0 wakepy-1.0.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
## Preamble
import sys
sys.path.append(r"C:\TUC\03 Scripts\Laborinstrumente\src") #Folder of the library
import Monitor224

# %%
## Configuration
monitor=Monitor224.device("a") #Only the channel connected to the instrument

# %%
## Command
monitor.getTemperature() #Read the temperature
# Out:
# 291.797
